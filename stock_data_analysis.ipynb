# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshayaKakde/Stock-Market-Data-Analysis-and-Reporting/blob/main/stock_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

data = pd.read_csv("combined_stock_data.csv")
data
# Out:
#              Date      Symbol Series  Prev Close     Open     High      Low  \
# 0      2000-01-03     DRREDDY     EQ     1396.50  1505.00  1508.25  1505.00
# 1      2000-01-04     DRREDDY     EQ     1508.25  1590.00  1628.95  1510.00
# 2      2000-01-05     DRREDDY     EQ     1628.95  1549.00  1650.00  1499.00
# 3      2000-01-06     DRREDDY     EQ     1568.05  1599.00  1693.50  1571.00
# 4      2000-01-07     DRREDDY     EQ     1661.55  1685.00  1685.00  1528.65
# ...           ...         ...    ...         ...      ...      ...      ...
# 70962  2016-11-21  HEROMOTOCO     EQ     2935.40  2942.95  2950.00  2895.10
# 70963  2016-11-22  HEROMOTOCO     EQ     2925.85  2940.05  3015.00  2933.00
# 70964  2016-11-23  HEROMOTOCO     EQ     2997.70  3030.00  3030.00  2995.00
# 70965  2016-11-24  HEROMOTOCO     EQ     3013.50  2999.90  3068.70  2973.75
# 70966  2016-11-25  HEROMOTOCO     EQ     3051.95  3055.00  3094.70  3028.00
#
#           Last    Close     VWAP  Volume      Turnover   Trades  \
# 0      1508.25  1508.25  1508.21   13280  2.002904e+12      NaN
# 1      1628.95  1628.95  1579.29   57142  9.024405e+12      NaN
# 2      1566.00  1568.05  1594.99  119697  1.909155e+13      NaN
# 3      1693.50  1661.55  1632.11  121966  1.990625e+13      NaN
# 4      1528.65  1529.10  1585.24   79641  1.262497e+13      NaN
# ...        ...      ...      ...     ...           ...      ...
# 70962  2925.25  2925.85  2921.18  539966  1.577336e+14  47795.0
# 70963  3010.00  2997.70  2979.86  581489  1.732757e+14  45464.0
# 70964  3012.00  3013.50  3011.78  545682  1.643474e+14  30192.0
# 70965  3040.00  3051.95  3038.94  802548  2.438893e+14  30376.0
# 70966  3056.95  3045.95  3061.84  412734  1.263727e+14  36081.0
#
#        Deliverable Volume  %Deliverble  Company Name  Industry  ISIN Code
# 0                     NaN          NaN           NaN       NaN        NaN
# 1                     NaN          NaN           NaN       NaN        NaN
# 2                     NaN          NaN           NaN       NaN        NaN
# 3                     NaN          NaN           NaN       NaN        NaN
# 4                     NaN          NaN           NaN       NaN        NaN
# ...                   ...          ...           ...       ...        ...
# 70962            379691.0       0.7032           NaN       NaN        NaN
# 70963            376486.0       0.6475           NaN       NaN        NaN
# 70964            385509.0       0.7065           NaN       NaN        NaN
# 70965            513296.0       0.6396           NaN       NaN        NaN
# 70966            279426.0          NaN           NaN       NaN        NaN
#
# [70967 rows x 18 columns]
