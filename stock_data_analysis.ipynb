# %%
# Out:
# Hello World

# %%
import pandas as pd

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/github_deployed/akashaya_kakde_resume_projects/Stock Market Data Analysis and Reporting/combined_stock_data.csv")
data
# Out:
# <ipython-input-8-a9a26208502f>:3: DtypeWarning: Columns (15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/github_deployed/akashaya_kakde_resume_projects/Stock Market Data Analysis and Reporting/combined_stock_data.csv")
#               Date      Symbol Series  Prev Close    Open     High      Low  \
# 0       2000-01-03     DRREDDY     EQ     1396.50  1505.0  1508.25  1505.00
# 1       2000-01-04     DRREDDY     EQ     1508.25  1590.0  1628.95  1510.00
# 2       2000-01-05     DRREDDY     EQ     1628.95  1549.0  1650.00  1499.00
# 3       2000-01-06     DRREDDY     EQ     1568.05  1599.0  1693.50  1571.00
# 4       2000-01-07     DRREDDY     EQ     1661.55  1685.0  1685.00  1528.65
# ...            ...         ...    ...         ...     ...      ...      ...
# 470429         NaN  ULTRACEMCO     EQ         NaN     NaN      NaN      NaN
# ...

# %%
# Out:
#             Date      Symbol Series  Prev Close    Open     High      Low  \
# 0     2000-01-03  ASIANPAINT     EQ      361.20   370.0   390.00   370.00
# 1     2000-01-04  ASIANPAINT     EQ      381.65   380.0   392.00   375.00
# 2     2000-01-05  ASIANPAINT     EQ      385.55   371.5   390.00   371.50
# 3     2000-01-06  ASIANPAINT     EQ      383.00   384.9   384.90   374.50
# 4     2000-01-07  ASIANPAINT     EQ      377.50   376.0   390.00   370.00
# ...          ...         ...    ...         ...     ...      ...      ...
# 5301  2021-04-26  ASIANPAINT     EQ     2517.95  2530.0  2575.00  2530.00
# 5302  2021-04-27  ASIANPAINT     EQ     2557.90  2545.0  2579.90  2534.00
# 5303  2021-04-28  ASIANPAINT     EQ     2574.35  2588.0  2620.25  2575.00
# 5304  2021-04-29  ASIANPAINT     EQ     2614.55  2630.0  2642.00  2570.00
# 5305  2021-04-30  ASIANPAINT     EQ     2613.45  2595.0  2605.80  2524.05
#
#         Last    Close     VWAP   Volume      Turnover   Trades  \
# ...

# %%
# Out:
# Combined CSV file created successfully.
